# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\mythi\OneDrive\Desktop\loan_dataset.csv")

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data['Gender'].replace(['Male','Female'],[0,1],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\2598697317.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].replace(['Male','Female'],[0,1],inplace=True)
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\2598697317.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['Married'].replace(['Yes','No'],[1,0],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\2061411164.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Married'].replace(['Yes','No'],[1,0],inplace=True)
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\2061411164.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['Self_Employed'].replace(['Yes','No'],[1,0],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\844253775.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Self_Employed'].replace(['Yes','No'],[1,0],inplace=True)
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\844253775.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['Education'].replace(['Graduate','Not Graduate'],[1,0],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\507295454.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Education'].replace(['Graduate','Not Graduate'],[1,0],inplace=True)
# ...

# %%
data["Property_Area"].replace(["Semiurban",'Urban',"Rural"],[1,0,2],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\2136521314.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Property_Area"].replace(["Semiurban",'Urban',"Rural"],[1,0,2],inplace=True)
# ...

# %%
import seaborn as sns
sns.histplot(data['Gender'],kde=True)
sns.histplot(data['Married'],kde=True)
sns.histplot(data['Education'],kde=True)
sns.histplot(data['Self_Employed'],kde=True)
# Out:
# c:\Users\mythi\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\mythi\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\mythi\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.histplot(data['Dependents'],kde=True)
# Out:
# c:\Users\mythi\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Dependents', ylabel='Count'>

# %%
data['Gender'].fillna(data['Gender'].median(),inplace=True)
data['Married'].fillna(data['Married'].median(),inplace=True)
data['Education'].fillna(data['Education'].median(),inplace=True)
data['Self_Employed'].fillna(data['Self_Employed'].median(),inplace=True)

# %%
data['Dependents'].replace(['3+'],[3],inplace=True)
data['Dependents'].fillna(data['Dependents'].median(),inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\3449812088.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].replace(['3+'],[3],inplace=True)

# %%
data['LoanAmount'].fillna(data['LoanAmount'].median(),inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\3641521672.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(data['LoanAmount'].median(),inplace=True)

# %%
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].median(),inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\1169899320.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].median(),inplace=True)

# %%
data['Credit_History'].fillna(data['Credit_History'].median(),inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\85885640.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Credit_History'].fillna(data['Credit_History'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
data["Loan_Status"].replace(["Y",'N'],[1,0],inplace=True)
# Out:
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\1329169860.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Loan_Status"].replace(["Y",'N'],[1,0],inplace=True)
# C:\Users\mythi\AppData\Local\Temp\ipykernel_4480\1329169860.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
Loan_approved=data[data.Loan_Status==1]
print(Loan_approved.shape)
Loan_disapproved=data[data.Loan_Status==0]
print(Loan_disapproved.shape)
# Out:
# (422, 13)
# (192, 13)

# %%
Loan_approves_sample=Loan_approved.sample(n=192)
Loan_approves_sample
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 11   LP001027     0.0      1.0          2          1            0.0
# 345  LP002129     0.0      1.0          0          1            0.0
# 326  LP002068     0.0      0.0          0          1            0.0
# 277  LP001904     0.0      1.0          0          1            0.0
# 439  LP002407     1.0      1.0          0          0            1.0
# ..        ...     ...      ...        ...        ...            ...
# 188  LP001644     0.0      1.0          0          1            1.0
# 446  LP002434     0.0      1.0          2          0            0.0
# 133  LP001482     0.0      1.0          0          1            1.0
# 520  LP002689     0.0      1.0          2          0            0.0
# 147  LP001518     0.0      1.0          1          1            0.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 11              2500             1840.0       109.0             360.0
# ...

# %%
Loanstatus=pd.concat([Loan_approves_sample,Loan_disapproved],axis=0)
Loanstatus.head()
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 11   LP001027     0.0      1.0          2          1            0.0
# 345  LP002129     0.0      1.0          0          1            0.0
# 326  LP002068     0.0      0.0          0          1            0.0
# 277  LP001904     0.0      1.0          0          1            0.0
# 439  LP002407     1.0      1.0          0          0            1.0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 11              2500             1840.0       109.0             360.0
# 345             2499             2458.0       160.0             360.0
# 326             4917                0.0       130.0             360.0
# 277             3103             1300.0        80.0             360.0
# 439             7142                0.0       138.0             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 11              1.0              0            1
# ...

# %%
Loanstatus['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    192
# 0    192
# Name: count, dtype: int64

# %%
data["Property_Area"].value_counts()
# Out:
# Property_Area
# 1    233
# 0    202
# 2    179
# Name: count, dtype: int64

# %%
#data["Property_Area"].replace(["Semiurban",'Urban',"Rural"],[1,0,2],inplace=True)

# %%
x=Loanstatus.drop(columns=['Loan_ID','Loan_Status',],axis=1)
y=Loanstatus['Loan_Status']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(x)
standardized_data
# Out:
# array([[-0.45139977,  0.77459667,  1.21985972, ...,  0.27648738,
#          0.5372063 , -1.20361202],
#        [-0.45139977,  0.77459667, -0.71578545, ...,  0.27648738,
#          0.5372063 ,  0.02888669],
#        [-0.45139977, -1.29099445, -0.71578545, ...,  0.27648738,
#         -1.86148228,  1.2613854 ],
#        ...,
#        [ 2.2153312 , -1.29099445,  2.1876823 , ..., -2.34718197,
#          0.5372063 , -1.20361202],
#        [-0.45139977,  0.77459667, -0.71578545, ..., -2.34718197,
#          0.5372063 , -1.20361202],
#        [ 2.2153312 , -1.29099445, -0.71578545, ...,  0.27648738,
#         -1.86148228,  0.02888669]])

# %%
x = standardized_data
y= Loanstatus['Loan_Status']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=5, stratify=y)

# %%
print(x.shape)
# Out:
# (384, 11)

# %%
print(y.shape)
# Out:
# (384,)

# %%
model = svm.SVC()

# %%
model.fit(X_train,Y_train)
# Out:
# SVC()

# %%
y_train_pred = model.predict(X_train)

# %%
accuracy_train = accuracy_score(y_train_pred, Y_train)
accuracy_train
# Out:
# 0.7785016286644951

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_pred,Y_test)
accuracy
# Out:
# 0.6623376623376623

# %%
report = classification_report(Y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        38
#            1       0.63      0.82      0.71        39
#
#     accuracy                           0.66        77
#    macro avg       0.68      0.66      0.65        77
# weighted avg       0.68      0.66      0.65        77

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
#training the Logistic Regression model with training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train) 
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.7328990228013029

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test) 
print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on test data :  0.6233766233766234

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
#training the Logistic Regression model with training data
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
X_train_prediction = rf_model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train) 
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  1.0

# %%
X_test_prediction = rf_model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test) 
print('Accuracy on test data : ', test_data_accuracy)
# Out:
# Accuracy on test data :  0.6493506493506493

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error
X_train_prediction = lr_model.predict(X_train)
train_mse = mean_squared_error(Y_test, y_pred)
print(f"Mean Squared Error: {train_mse}")
# Out:
# Mean Squared Error: 0.33766233766233766

# %%
X_test_prediction = lr_model.predict(X_test)
print(X_test_prediction)
test_mse = mean_squared_error(X_test_prediction, Y_test) 
print('Accuracy on test data : ', test_mse)
# Out:
# [ 0.70384388  0.5857708   0.53993357  0.62627333 -0.0646561   0.55291135
#   0.15813587  0.62107642  0.60411986  0.5416337   0.57516221  0.59977313
#   0.43097542  0.49862853  0.93824329  0.75152394  0.33102178  0.57562519
#   0.43730993  0.62964209 -0.05295072  0.57579101  0.6972641   0.55703171
#   0.57520479  0.7514899  -0.13994173 -0.14840947  0.55165044  0.55989492
#   0.59028623 -0.03268284 -0.10714338  0.51705299 -0.09322544  0.56931527
#   0.65250715  0.65387982  0.72804969  0.14309757 -0.09660642  0.60402635
#   0.67666401 -0.08486537  0.74944384  0.5661756   0.57401671  0.56633291
#   0.49192044  0.47557786  0.5901013   0.53937904  0.77973702 -0.05940402
#   0.45460599  0.70941018 -0.02345305  0.73442365  0.65866218  0.60939459
#   0.71020625  0.78431567 -0.20335762  0.00214845  0.48560249  0.61664942
#  -0.15343299  0.69157659  0.57377866  0.66622318  0.71908094  0.80381054
#  -0.05053897  0.69035011 -0.07756295  0.69621532  0.69689528]
# ...
